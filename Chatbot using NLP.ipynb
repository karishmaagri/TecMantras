# %%
from nltk.chat.util import Chat, reflections

#Create the chatbot list of recognizable patterns and its response to those patterns.
#TO do this, we will create a variable called 'pairs'

#Pairs is a list of patterns and response
pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, how are you today?",]
    ],
    [
        r"(.*)help(.*)",
        ["I can help you. How can I assist you?",]
    ],
    [
        r"what is your name ?",
        ["My name is thecleverprogrammer, but you can call me Robot. I'm a chatbot.",]
    ],
    [
        r"how are you (.*) ?",
        ["I'm doing very well.", "I am great!"]
    ],
    [
        r"sorry (.*)",
        ["It's alright.", "It's OK, never mind that."]
    ],
    [
        r"i'm (.*) (good|well|okay|ok)",
        ["Nice to hear that.", "Alright, great!"]
    ],
    [
        r"(hi|hey|hello|hola|holla(.*)",
        ["Hello!" "Hey there!"]
    ],
    [
        r"what do you want ?",
        ["Make me an offer I can't refuse.",]
    ],
    [
        r"(.*)created(.*)",
        ["Nandini Ravi created me using Python's NLTK library.", "Nandini :)"]
    ],
    [
        r"(.*) (location|city) ?",
        ["I am located in Maharashtra, India.",]
    ],
    [
        r"is it raining in (.*)",
        ["No rain in the past 4 days here in %1.", "In %1, there is a 50% chance of rain.",]
    ],
    [
        r"how is your health (.*)",
        ["Health is very important, but I am a computer, so I don't need to worry about my health.",]
    ],
    [
        r"(.*)(sports|game|sport)(.*)",
        ["I'm a very big fan of Cricket.",]
    ],
    [
        r"who is your favorite (Cricketer|Batman)?",
        ["Shubman Gill is my favorite.",]
    ],
    [
        r"quit",
        ["Bye for now, see you soon! :)", "It was nice talking to you. See you soon! :)"]
    ],
    [
        r"(.*)",
        ["Our customer service will reach out to you. Please leave your number and write your query to us."]
    ],
]

#default message at the start of chat
print("Hi, I'm thecleverprogrammer and I like to chat!")
print("Please type in lowercase English to start a conversation. Type 'quit' to leave.")

#Create chat bot
chat = Chat(pairs, reflections)

#start conversation
chat.converse()
# Out:
# Hi, I'm thecleverprogrammer and I like to chat!
# Please type in lowercase English to start a conversation. Type 'quit' to leave.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 79
#      76 print("Please type in lowercase English to start a conversation. Type 'quit' to leave.")
#      78 #Create chat bot
# ---> 79 chat = Chat(pairs, reflections)
#      81 #start conversation
#      82 chat.converse()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nltk\chat\util.py:51, in Chat.__init__(self, pairs, reflections)
#      35 def __init__(self, pairs, reflections={}):
#      36     """
#      37     Initialize the chatbot.  Pairs is a list of patterns and responses.  Each
#      38     pattern is a regular expression matching the user's statement or question,
#    (...)
#      48     :rtype: None
#      49     """
# ---> 51     self._pairs = [(re.compile(x, re.IGNORECASE), y) for (x, y) in pairs]
#      52     self._reflections = reflections
#      53     self._regex = self._compile_reflections()
#
# File C:\ProgramData\anaconda3\Lib\re\__init__.py:228, in compile(pattern, flags)
#     226 def compile(pattern, flags=0):
#     227     "Compile a regular expression pattern, returning a Pattern object."
# --> 228     return _compile(pattern, flags)
#
# File C:\ProgramData\anaconda3\Lib\re\__init__.py:307, in _compile(pattern, flags)
#     301     import warnings
#     302     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     303             "as it is an undocumented flag "
#     304             "without an obvious purpose. "
#     305             "Don't use it.",
#     306             DeprecationWarning)
# --> 307 p = _compiler.compile(pattern, flags)
#     308 if flags & DEBUG:
#     309     return p
#
# File C:\ProgramData\anaconda3\Lib\re\_compiler.py:745, in compile(p, flags)
#     743 if isstring(p):
#     744     pattern = p
# --> 745     p = _parser.parse(p, flags)
#     746 else:
#     747     pattern = None
#
# File C:\ProgramData\anaconda3\Lib\re\_parser.py:979, in parse(str, flags, state)
#     976 state.flags = flags
#     977 state.str = str
# --> 979 p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     980 p.state.flags = fix_flags(str, p.state.flags)
#     982 if source.next is not None:
#
# File C:\ProgramData\anaconda3\Lib\re\_parser.py:460, in _parse_sub(source, state, verbose, nested)
#     458 start = source.tell()
#     459 while True:
# --> 460     itemsappend(_parse(source, state, verbose, nested + 1,
#     461                        not nested and not items))
#     462     if not sourcematch("|"):
#     463         break
#
# File C:\ProgramData\anaconda3\Lib\re\_parser.py:864, in _parse(source, state, verbose, nested, first)
#     862 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     863 if not source.match(")"):
# --> 864     raise source.error("missing ), unterminated subpattern",
#     865                        source.tell() - start)
#     866 if group is not None:
#     867     state.closegroup(group, p)
#
# error: missing ), unterminated subpattern at position 0
